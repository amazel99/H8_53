# %% [markdown]
# ### By : Daniel
# ###         PYTN053ONL006

# %% [markdown]
# <img src = "https://global-uploads.webflow.com/5f0d53c042a9ed6288de7f8d/5f6337ae2cfaa10946ceeb06_Hacktiv8%20logo%20horizontal%2001%20black-p-500.png" width = 400>
# <h1 align=center><font size = 5>Hacktiv8 PTP Introduction to Data Science Projects 2 // Statistical Treatment for Datasets</font></h1>

# %% [markdown]
# Title: Hacktiv8 PTP Introduction to Data Science Projects 2: Statistical Treatment for Datasets Starter Notebook\
# Last Updated: September 20, 2020\
# Author: Raka Ardhi

# %% [markdown]
# ## NYC Property Sales Introduction
#
# The aim of this projects is to introduce you to practical statistic with Python as concrete and as consistent as possible. Using what you’ve learned; download the NYC Property Sales Dataset from Kaggle. This dataset is a record of every building or building unit (apartment, etc.) sold in the New York City property market over a 12-month period.
#
# This dataset contains the location, address, type, sale price, and sale date of building units sold. A reference on the trickier fields:
#
# * `BOROUGH`: A digit code for the borough the property is located in; in order these are Manhattan (1), Bronx (2), Brooklyn (3), Queens (4), and Staten Island (5).
# * `BLOCK`; `LOT`: The combination of borough, block, and lot forms a unique key for property in New York City. Commonly called a BBL.
# * `BUILDING CLASS AT PRESENT` and `BUILDING CLASS AT TIME OF SALE`: The type of building at various points in time.
#
# Note that because this is a financial transaction dataset, there are some points that need to be kept in mind:
#
# * Many sales occur with a nonsensically small dollar amount: $0 most commonly. These sales are actually transfers of deeds between parties: for example, parents transferring ownership to their home to a child after moving out for retirement.
# * This dataset uses the financial definition of a building/building unit, for tax purposes. In case a single entity owns the building in question, a sale covers the value of the entire building. In case a building is owned piecemeal by its residents (a condominium), a sale refers to a single apartment (or group of apartments) owned by some individual.
#
# Formulate a question and derive a statistical hypothesis test to answer the question. You have to demonstrate that you’re able to make decisions using data in a scientific manner. Examples of questions can be:
#
# * Is there a difference in unit sold between property built in 1900-2000 and 2001 so on?
# * Is there a difference in unit sold based on building category?
# * What can you discover about New York City real estate by looking at a year's worth of raw transaction records? Can you spot trends in the market?
#
# Please make sure that you have completed the lesson for this course, namely Python and Practical Statistics which is part of this Program.
#
# **Note:** You can take a look at Project Rubric below:
#
# | Code Review |  |
# | :--- | :--- |
# | CRITERIA | SPECIFICATIONS |
# | Mean | Student implement mean to specifics column/data using pandas, numpy, or scipy|
# | Median | Student implement median to specifics column/data using pandas, numpy, or scipy|
# | Modus | Student implement modus to specifics column/data using pandas, numpy, or scipy|
# | Central Tendencies | Implementing Central Tendencies through dataset |
# | Box Plot | Implementing Box Plot to visualize spesific data |
# | Z-Score | Implementing Z-score concept to specific data |
# | Probability Distribution | Student analyzing distribution of data and gain insight from the distribution |
# | Intervals | Implementing Confidence or Prediction Intervals |
# | Hypotesis Testing | Made 1 Hypotesis and get conclusion from data |
# | Preprocessing | Student preprocess dataset before applying the statistical treatment. |
# | Does the code run without errors? | The code runs without errors. All code is functional and formatted properly. |
#
# | Readability |  |
# | :--- | :--- |
# | CRITERIA | SPECIFICATIONS |
# | Well Documented | All cell in notebook are well documented with markdown above each cell explaining the code|
#
# | Analysis |  |
# | :--- | :--- |
# | CRITERIA | SPECIFICATIONS |
# |Overall Analysis| Gain an insight/conclusion of overall plots that answer the hypotesis |
#
# **Focus on "Graded-Function" sections.**
#
# ------------

# %% [markdown]
# ## Data Preparation
#
# Load the library you need.
#
# Get your NYC property data from [here](https://www.kaggle.com/new-york-city/nyc-property-sales) and load the dataframe to your notebook.

# %%
# Gimport math
import math
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.stats
import seaborn as sns
import statistics
import statsmodels.api as sm

# %%
# Load your dataset here
df = pd.read_csv('nyc-rolling-sales.csv')
print ('Data read into a pandas dataframe!')
# Out:
# Data read into a pandas dataframe!

# %% [markdown]
# Let's view the top 5 rows of the dataset using the `head()` function.

# %%
# Write your syntax here
df.head()
# Out:
#    Unnamed: 0  BOROUGH   NEIGHBORHOOD  \
# 0           4        1  ALPHABET CITY
# 1           5        1  ALPHABET CITY
# 2           6        1  ALPHABET CITY
# 3           7        1  ALPHABET CITY
# 4           8        1  ALPHABET CITY
#
#                        BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  BLOCK  \
# 0  07 RENTALS - WALKUP APARTMENTS                                2A    392
# 1  07 RENTALS - WALKUP APARTMENTS                                 2    399
# 2  07 RENTALS - WALKUP APARTMENTS                                 2    399
# 3  07 RENTALS - WALKUP APARTMENTS                                2B    402
# 4  07 RENTALS - WALKUP APARTMENTS                                2A    404
#
#    LOT EASE-MENT BUILDING CLASS AT PRESENT                 ADDRESS  ...  \
# 0    6                                  C2            153 AVENUE B  ...
# 1   26                                  C7   234 EAST 4TH   STREET  ...
# ...

# %% [markdown]
# We can also veiw the bottom 5 rows of the dataset using the `tail()` function.

# %%
# Write your syntax here
df.tail()
# Out:
#        Unnamed: 0  BOROUGH NEIGHBORHOOD  \
# 84543        8409        5      WOODROW
# 84544        8410        5      WOODROW
# 84545        8411        5      WOODROW
# 84546        8412        5      WOODROW
# 84547        8413        5      WOODROW
#
#                            BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  \
# 84543  02 TWO FAMILY DWELLINGS                                        1
# 84544  02 TWO FAMILY DWELLINGS                                        1
# 84545  02 TWO FAMILY DWELLINGS                                        1
# 84546  22 STORE BUILDINGS                                             4
# 84547  35 INDOOR PUBLIC AND CULTURAL FACILITIES                       4
#
#        BLOCK  LOT EASE-MENT BUILDING CLASS AT PRESENT                ADDRESS  \
# 84543   7349   34                                  B9          37 QUAIL LANE
# 84544   7349   78                                  B9       32 PHEASANT LANE
# ...

# %% [markdown]
# BOROUGH: A digit code for the borough the property is located in; in order these are Manhattan (1), Bronx (2), Brooklyn (3), Queens (4), and Staten Island (5).

# %% [markdown]
# To view the dimensions of the dataframe, we use the `.shape` parameter. Expected result: (84548, 22)

# %%
# Write your syntax here
df.shape
# Out:
# (84548, 22)

# %% [markdown]
# According to this official page, Ease-ment is "is a right, such as a right of way, which allows an entity to make limited use of another’s real property. For example: MTA railroad tracks that run across a portion of another property". Also, the Unnamed column is not mentioned and was likely used for iterating through records. So, those two columns are removed for now.

# %%
# Drop 'Unnamed: 0' and 'EASE-MENT' features using .drop function
df.drop(columns = ['Unnamed: 0', 'EASE-MENT'], inplace=True)
df
# Out:
#        BOROUGH   NEIGHBORHOOD                      BUILDING CLASS CATEGORY  \
# 0            1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 1            1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 2            1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 3            1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 4            1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# ...        ...            ...                                          ...
# 84543        5        WOODROW  02 TWO FAMILY DWELLINGS
# 84544        5        WOODROW  02 TWO FAMILY DWELLINGS
# 84545        5        WOODROW  02 TWO FAMILY DWELLINGS
# 84546        5        WOODROW  22 STORE BUILDINGS
# 84547        5        WOODROW  35 INDOOR PUBLIC AND CULTURAL FACILITIES
#
#       TAX CLASS AT PRESENT  BLOCK  LOT BUILDING CLASS AT PRESENT  \
# 0                       2A    392    6                        C2
# 1                        2    399   26                        C7
# ...

# %% [markdown]
# Let's view Dtype of each features in dataframe using `.info()` function.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84548 entries, 0 to 84547
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   BOROUGH                         84548 non-null  int64
#  1   NEIGHBORHOOD                    84548 non-null  object
#  2   BUILDING CLASS CATEGORY         84548 non-null  object
#  3   TAX CLASS AT PRESENT            84548 non-null  object
#  4   BLOCK                           84548 non-null  int64
#  5   LOT                             84548 non-null  int64
#  6   BUILDING CLASS AT PRESENT       84548 non-null  object
#  7   ADDRESS                         84548 non-null  object
#  8   APARTMENT NUMBER                84548 non-null  object
#  9   ZIP CODE                        84548 non-null  int64
#  10  RESIDENTIAL UNITS               84548 non-null  int64
#  11  COMMERCIAL UNITS                84548 non-null  int64
# ...

# %% [markdown]
# It looks like empty records are not being treated as NA. We convert columns to their appropriate data types to obtain NAs.

# %%
#First, let's check which columns should be categorical
print('Column name')
for col in df.columns:
    if df[col].dtype=='object':
        print(col, df[col].nunique())
# Out:
# Column name
# NEIGHBORHOOD 254
# BUILDING CLASS CATEGORY 47
# TAX CLASS AT PRESENT 11
# BUILDING CLASS AT PRESENT 167
# ADDRESS 67563
# APARTMENT NUMBER 3989
# LAND SQUARE FEET 6062
# GROSS SQUARE FEET 5691
# BUILDING CLASS AT TIME OF SALE 166
# SALE PRICE 10008
# SALE DATE 364

# %%
# LAND SQUARE FEET,GROSS SQUARE FEET, SALE PRICE, BOROUGH should be numeric. 
# SALE DATE datetime format.
# categorical: NEIGHBORHOOD, BUILDING CLASS CATEGORY, TAX CLASS AT PRESENT, BUILDING CLASS AT PRESENT,
# BUILDING CLASS AT TIME OF SALE, TAX CLASS AT TIME OF SALE,BOROUGH 

numer = ['LAND SQUARE FEET','GROSS SQUARE FEET', 'SALE PRICE', 'BOROUGH']
for col in numer: # coerce for missing values
    df[col] = pd.to_numeric(df[col], errors='coerce')

categ = ['NEIGHBORHOOD', 'BUILDING CLASS CATEGORY', 'TAX CLASS AT PRESENT', 'BUILDING CLASS AT PRESENT', 'BUILDING CLASS AT TIME OF SALE', 'TAX CLASS AT TIME OF SALE']
for col in categ:
    df[col] = df[col].astype('category')

df['SALE DATE'] = pd.to_datetime(df['SALE DATE'], errors='coerce')

# %% [markdown]
# Our dataset is ready for checking missing values.

# %%
missing = df.isnull().sum()/len(df)*100

print(pd.DataFrame([missing[missing>0],pd.Series(df.isnull().sum()[df.isnull().sum()>1000])], index=['percent missing','how many missing']))
# Out:
#                   LAND SQUARE FEET  GROSS SQUARE FEET   SALE PRICE
# percent missing          31.049818          32.658372     17.22217
# how many missing      26252.000000       27612.000000  14561.00000

# %% [markdown]
# Around 30% of GROSS SF and LAND SF are missing. Furthermore, around 17% of SALE PRICE is also missing.

# %% [markdown]
# We can fill in the missing value from one column to another, which will help us reduce missing values. Expected values:
#
# (6, 20)
#
# (1366, 20)

# %%
print(df[(df['LAND SQUARE FEET'].isnull()) & (df['GROSS SQUARE FEET'].notnull())].shape)
print(df[(df['LAND SQUARE FEET'].notnull()) & (df['GROSS SQUARE FEET'].isnull())].shape)
# Out:
# (6, 20)
# (1366, 20)

# %% [markdown]
# There are 1372 rows that can be filled in with their approximate values.

# %%
df['LAND SQUARE FEET'] = df['LAND SQUARE FEET'].mask((df['LAND SQUARE FEET'].isnull()) & (df['GROSS SQUARE FEET'].notnull()), df['GROSS SQUARE FEET'])
df['GROSS SQUARE FEET'] = df['GROSS SQUARE FEET'].mask((df['LAND SQUARE FEET'].notnull()) & (df['GROSS SQUARE FEET'].isnull()), df['LAND SQUARE FEET'])

# %%
#  Check for duplicates before

print(sum(df.duplicated()))

df[df.duplicated(keep=False)].sort_values(['NEIGHBORHOOD', 'ADDRESS']).head(10)

# df.duplicated() automatically excludes duplicates, to keep duplicates in df we use keep=False

# in df.duplicated(df.columns) we can specify column names to look for duplicates only in those mentioned columns.
# Out:
# 765
#        BOROUGH   NEIGHBORHOOD                      BUILDING CLASS CATEGORY  \
# 76286        5       ANNADALE  02 TWO FAMILY DWELLINGS
# 76287        5       ANNADALE  02 TWO FAMILY DWELLINGS
# 76322        5       ANNADALE  05 TAX CLASS 1 VACANT LAND
# 76323        5       ANNADALE  05 TAX CLASS 1 VACANT LAND
# 76383        5  ARDEN HEIGHTS  01 ONE FAMILY DWELLINGS
# 76384        5  ARDEN HEIGHTS  01 ONE FAMILY DWELLINGS
# 76643        5       ARROCHAR  02 TWO FAMILY DWELLINGS
# 76644        5       ARROCHAR  02 TWO FAMILY DWELLINGS
# 50126        4        ASTORIA  03 THREE FAMILY DWELLINGS
# 50127        4        ASTORIA  03 THREE FAMILY DWELLINGS
#
#       TAX CLASS AT PRESENT  BLOCK  LOT BUILDING CLASS AT PRESENT  \
# 76286                    1   6350    7                        B2
# 76287                    1   6350    7                        B2
# 76322                   1B   6459   28                        V0
# ...

# %% [markdown]
# The dataframe has 765 duplicated rows (exluding the original rows).

# %%
df.drop_duplicates(inplace=True)

print(sum(df.duplicated()))
# Out:
# 0

# %% [markdown]
# ## Exploratory data analysis

# %% [markdown]
# Now, let's get a simple descriptive statistics with `.describe()` function for `COMMERCIAL UNITS` features.

# %%
df[df['COMMERCIAL UNITS']==0].describe()
# Out:
#             BOROUGH         BLOCK           LOT      ZIP CODE  \
# count  78777.000000  78777.000000  78777.000000  78777.000000
# mean       3.004329   4273.781015    395.422420  10722.737068
# std        1.298594   3589.241940    671.604654   1318.493961
# min        1.000000      1.000000      1.000000      0.000000
# 25%        2.000000   1330.000000     23.000000  10304.000000
# 50%        3.000000   3340.000000     52.000000  11209.000000
# 75%        4.000000   6361.000000   1003.000000  11357.000000
# max        5.000000  16322.000000   9106.000000  11694.000000
#
#        RESIDENTIAL UNITS  COMMERCIAL UNITS   TOTAL UNITS  LAND SQUARE FEET  \
# count       78777.000000           78777.0  78777.000000      5.278000e+04
# mean            1.691737               0.0      1.724133      3.140140e+03
# std             9.838994               0.0      9.835016      2.929999e+04
# min             0.000000               0.0      0.000000      0.000000e+00
# ...

# %% [markdown]
# Let us try to understand the columns. Above table shows descriptive statistics for the numeric columns.
#
# - There are zipcodes with 0 value
# - Can block/lot numbers go up to 16322?
# - Most of the properties have 2 unit and maximum of 1844 units? The latter might mean some company purchased a building. This should be treated as an outlier.
# - Other columns also have outliers which needs further investigation.
# - Year column has a year with 0
# - Most sales prices less than 10000 can be treated as gift or transfer fees.

# %% [markdown]
# Now, let's get a simple descriptive statistics with `.describe()` function for `RESIDENTIAL UNITS` features.
#
# Function below are graded function. (1 Points)

# %%
# Write your function below
df[df['RESIDENTIAL UNITS']==0].describe()
# Graded-Funtion Begin (~1 Lines)

# Graded-Funtion End
# Out:
#             BOROUGH         BLOCK           LOT      ZIP CODE  \
# count  24546.000000  24546.000000  24546.000000  24546.000000
# mean       2.542084   3355.267172    283.943412  10321.514626
# std        1.334486   3091.222257    570.045258   2135.406385
# min        1.000000      1.000000      1.000000      0.000000
# 25%        1.000000   1158.000000     12.000000  10023.000000
# 50%        3.000000   1947.000000     38.000000  11004.000000
# 75%        4.000000   5390.750000    135.000000  11354.000000
# max        5.000000  16317.000000   9056.000000  11694.000000
#
#        RESIDENTIAL UNITS  COMMERCIAL UNITS   TOTAL UNITS  LAND SQUARE FEET  \
# count            24546.0      24546.000000  24546.000000      9.503000e+03
# mean                 0.0          0.459382      0.563350      7.416797e+03
# std                  0.0         15.826020     15.825945      8.032892e+04
# min                  0.0          0.000000      0.000000      0.000000e+00
# ...

# %% [markdown]
# Write your findings below:

# %% [markdown]
# Use `.value_counts` function to count total value of `BOROUGH` features. Expected value:
#
# 4    26548\
# 3    23843\
# 1    18102\
# 5     8296\
# 2     6994\
# Name: BOROUGH, dtype: int64

# %%
# Write your syntax below
df.BOROUGH.value_counts()
# Out:
# 4    26548
# 3    23843
# 1    18102
# 5     8296
# 2     6994
# Name: BOROUGH, dtype: int64

# %% [markdown]
# From here, we can calculate the mean for each Borough. Use `.mean()` function to calculate mean.
#
# Function below are graded function. (1 Points)

# %%
df4 = df[(df.BOROUGH == 4)]
df4_tot = df4.groupby('NEIGHBORHOOD')['TOTAL UNITS'].sum()
df4_tot
# Out:
# NEIGHBORHOOD
# AIRPORT LA GUARDIA     15
# ALPHABET CITY           0
# ANNADALE                0
# ARDEN HEIGHTS           0
# ARROCHAR                0
#                      ...
# WOODHAVEN             754
# WOODLAWN                0
# WOODROW                 0
# WOODSIDE              782
# WYCKOFF HEIGHTS         0
# Name: TOTAL UNITS, Length: 254, dtype: int64

# %%
df4_native_mean = df4_tot.mean()
df4_stats_mean = statistics.mean(df4_tot)
df4_np_mean = np.mean(df4_tot)

print('Native Mean for Borough 4    :', df4_native_mean )
print('Statistic Mean for Borough 4 :', df4_stats_mean)
print('Numpy Mean for Borough 4     :', df4_np_mean)
# Out:
# Native Mean for Borough 4    : 199.51968503937007
# Statistic Mean for Borough 4 : 199.51968503937007
# Numpy Mean for Borough 4     : 199.51968503937007

# %% [markdown]
# From here, we can calculate the median for each Borough. Use `.median()` function to calculate median.
#
# Function below are graded function. (1 Points)

# %%
df4_np_median = np.median(df4_tot)
df4_stats_median = statistics.median(df4_tot)
df4_stats_median_low = statistics.median_low(df4_tot)
df4_stats_median_high = statistics.median_high(df4_tot)

print('Numpy Median for Borough 4             :', df4_np_median)
print('Statistic Median for Borough 4         :', df4_stats_median)
print('Statistic Median Low for Borough 4     :', df4_stats_median_low)
print('Statistic Median High for Borough 4     :', df4_stats_median_high)
# Out:
# Numpy Median for Borough 4             : 0.0
# Statistic Median for Borough 4         : 0.0
# Statistic Median Low for Borough 4     : 0
# Statistic Median High for Borough 4     : 0

# %% [markdown]
# From here, we can calculate the mode for each Borough.
#
# Function below are graded function. (1 Points)

# %%
df4_series = pd.Series(df4_tot)
df4_stats_mode = statistics.mode(df4_tot)
df4_scipy_mode = scipy.stats.mode(df4_tot)
df4_series_mode = df4_series.mode()

print("Statistics Mode for Borough 4 :", df4_stats_mode)
print("Scipy Mode for Borough 4      :", df4_scipy_mode, df4_scipy_mode.mode[0], df4_scipy_mode.count[0])
print("Series Mode for Borough 4     :", df4_series_mode)
# Out:
# Statistics Mode for Borough 4 : 0
# Scipy Mode for Borough 4      : ModeResult(mode=array([0], dtype=int64), count=array([196])) 0 196
# Series Mode for Borough 4     : 0    0
# dtype: int64

# %% [markdown]
# From here, we can calculate the Range for each Borough.
#
# Function below are graded function. (1 Points)

# %%
df4_np_range = np.amax(df4_tot) - np.amin(df4_tot)

print("Range for Borough 4 :", df4_np_range)
# Out:
# Range for Borough 4 : 4523

# %% [markdown]
# From here, we can calculate the Variance for each Borough.
#
# Function below are graded function. (1 Points)

# %%
df4_stats_var = statistics.variance(df4_tot)
df4_np_var = np.var(df4_tot, ddof=1)
df4_series_var = df4_series.var(ddof=1)

print('Statistic Variance for Borough 4 :', df4_stats_var)
print('Numpy Variance for Borough 4     :', df4_np_var)
print('Series Variance for Borough 4    :', df4_series_var)
# Out:
# Statistic Variance for Borough 4 : 338700.10040148144
# Numpy Variance for Borough 4     : 338700.1004014809
# Series Variance for Borough 4    : 338700.1004014809

# %% [markdown]
# From here, we can calculate the SD for each Borough.
#
# Function below are graded function. (1 Points)

# %%
df4_result1 = scipy.stats.describe(df4_tot, ddof=1, bias=False)
df4_result2 = df4_tot.describe()

print('Result 1 for Borough 4 :', df4_result1)
print('Result 2 for Borough 4 :', df4_result2)
# Out:
# Result 1 for Borough 4 : DescribeResult(nobs=254, minmax=(0, 4523), mean=199.51968503937007, variance=338700.1004014814, skewness=4.521749814866915, kurtosis=24.574235930122185)
# Result 2 for Borough 4 : count     254.000000
# mean      199.519685
# std       581.979467
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max      4523.000000
# Name: TOTAL UNITS, dtype: float64

# %% [markdown]
# Now we can analyze Probability Distibution below.
#
# Function below are graded function. (1 Points)

# %%
sns.histplot(
    x=df4_tot, stat="probability", bins=100, kde=True, color="skyblue",
    alpha=1, linewidth=15
)
plt.xlabel("Range Data")
plt.ylabel("Probability")
plt.show()

# %% [markdown]
# Now we can analyze Confidence Intervals below.
#
# Function below are graded function. (1 Points)

# %%
z_score = 1.96
total_df4 = 26548
df4_mean = 199.519685
df4_std = 581.979467

se_mean_df4 = df4_std / np.sqrt(total_df4) 
print("Standard Error for Borough 4 :", se_mean_df4)
# Out:
# Standard Error for Borough 4 : 3.5718380380944397

# %%
lower_ci_mean_df4 = df4_mean - z_score*se_mean_df4
upper_ci_mean_df4 = df4_mean + z_score*se_mean_df4

print("CI for proportion of Borough 4: [{}, {}]".format(
    lower_ci_mean_df4, upper_ci_mean_df4
))
# Out:
# CI for proportion of Borough 4: [192.5188824453349, 206.52048755466512]

# %% [markdown]
# Make your Hypothesis Testing below
#
# Function below are graded function. (1 Points)

# %%
df.head()
# Out:
#    BOROUGH   NEIGHBORHOOD                      BUILDING CLASS CATEGORY  \
# 0        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 1        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 2        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 3        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 4        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
#
#   TAX CLASS AT PRESENT  BLOCK  LOT BUILDING CLASS AT PRESENT  \
# 0                   2A    392    6                        C2
# 1                    2    399   26                        C7
# 2                    2    399   39                        C7
# 3                   2B    402   21                        C4
# 4                   2A    404   55                        C2
#
#                   ADDRESS APARTMENT NUMBER  ZIP CODE  RESIDENTIAL UNITS  \
# 0            153 AVENUE B                      10009                  5
# 1   234 EAST 4TH   STREET                      10009                 28
# ...

# %%
df.rename(columns={'BUILDING CLASS CATEGORY': 'BUILDING_CLASS_CATEGORY', 'TOTAL UNITS': 'TOTAL_UNITS', 'YEAR BUILT': 'YEAR_BUILT'}, inplace=True)
df.head()
# Out:
#    BOROUGH   NEIGHBORHOOD                      BUILDING_CLASS_CATEGORY  \
# 0        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 1        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 2        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 3        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 4        1  ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
#
#   TAX CLASS AT PRESENT  BLOCK  LOT BUILDING CLASS AT PRESENT  \
# 0                   2A    392    6                        C2
# 1                    2    399   26                        C7
# 2                    2    399   39                        C7
# 3                   2B    402   21                        C4
# 4                   2A    404   55                        C2
#
#                   ADDRESS APARTMENT NUMBER  ZIP CODE  RESIDENTIAL UNITS  \
# 0            153 AVENUE B                      10009                  5
# 1   234 EAST 4TH   STREET                      10009                 28
# ...

# %%
# Filtering unit sold from 1900 - 2000
df_sold1 = df[(df.YEAR_BUILT>=1900) & (df.YEAR_BUILT<=2000)]
df_1900_2000 = df_sold1.groupby('YEAR_BUILT')['TOTAL_UNITS'].sum()
df_1900_2000
# Out:
# YEAR_BUILT
# 1900    3891
# 1901    3813
# 1902      31
# 1903     133
# 1904     149
#         ...
# 1996     292
# 1997     267
# 1998     231
# 1999     403
# 2000     432
# Name: TOTAL_UNITS, Length: 101, dtype: int64

# %%
# Count the total sold from 1900 - 2000
total_sold_1900_2000 = df_1900_2000.sum()
print('Total Unit Sold from 1900 to 2000 :', total_sold_1900_2000)
# Out:
# Total Unit Sold from 1900 to 2000 : 151293

# %%
# Filtering unit sold from 2001 - 2017
df_sold2 = df[(df.YEAR_BUILT>=2001) & (df.YEAR_BUILT<=2021)]
df_2001_2017 = df_sold2.groupby('YEAR_BUILT')['TOTAL_UNITS'].sum()
df_2001_2017
# Out:
# YEAR_BUILT
# 2001     498
# 2002     681
# 2003     653
# 2004    1316
# 2005    1646
# 2006    1390
# 2007    2173
# 2008    1175
# 2009    1264
# 2010     477
# 2011     236
# 2012     355
# 2013    1741
# 2014    3550
# 2015    3842
# 2016    3333
# 2017     859
# Name: TOTAL_UNITS, dtype: int64

# %%
# Count the total sold from 2001 - so on
total_sold_2001_2017 = df_2001_2017.sum()
print('Total Unit Sold from 2001 to 2017 :', total_sold_2001_2017)
# Out:
# Total Unit Sold from 2001 to 2017 : 25189

# %%
# Filtering unit sold based on building category
df_category = df.groupby('BUILDING_CLASS_CATEGORY')['TOTAL_UNITS'].sum()
df_category
# Out:
# BUILDING_CLASS_CATEGORY
# 01 ONE FAMILY DWELLINGS                         18517
# 02 TWO FAMILY DWELLINGS                         32194
# 03 THREE FAMILY DWELLINGS                       13011
# 04 TAX CLASS 1 CONDOS                            1626
# 05 TAX CLASS 1 VACANT LAND                        243
# 06 TAX CLASS 1 - OTHER                             29
# 07 RENTALS - WALKUP APARTMENTS                  38137
# 08 RENTALS - ELEVATOR APARTMENTS                30424
# 09 COOPS - WALKUP APARTMENTS                     1202
# 10 COOPS - ELEVATOR APARTMENTS                  12382
# 11 SPECIAL CONDO BILLING LOTS                       0
# 11A CONDO-RENTALS                                2574
# 12 CONDOS - WALKUP APARTMENTS                     871
# 13 CONDOS - ELEVATOR APARTMENTS                 12423
# 14 RENTALS - 4-10 UNIT                           3537
# 15 CONDOS - 2-10 UNIT RESIDENTIAL                1216
# 16 CONDOS - 2-10 UNIT WITH COMMERCIAL UNIT         93
# ...

# %%
manhattan = df[df['BOROUGH'] == 1]
bronx = df[df['BOROUGH'] == 2]

n1 = len(manhattan)
mu1 = manhattan['TOTAL_UNITS'].mean()
sd1 = manhattan['TOTAL_UNITS'].std()

(n1, mu1, sd1)
# Out:
# (18102, 2.5972268257651088, 23.283373558631993)

# %%
n2 = len(bronx)
mu2 = bronx['TOTAL_UNITS'].mean()
sd2 = bronx['TOTAL_UNITS'].std()

(n2, mu2, sd2)
# Out:
# (6994, 3.510151558478696, 22.6815940552237)

# %%
sm.stats.ztest(manhattan['TOTAL_UNITS'].dropna(),
               bronx['TOTAL_UNITS'].dropna(),alternative='two-sided')
# Out:
# (-2.8049341240744905, 0.005032686435343669)

# %% [markdown]
# Write your final conclusion below.
#
# Your conclusion below are graded. (1 Points)

# %%
plt.figure(figsize=(7,4))
plt.title('Manhattan Total Units histogram',fontsize=16)
plt.hist(manhattan['TOTAL_UNITS'].dropna(),edgecolor='k',color='blue',bins=30)
plt.show()

plt.figure(figsize=(7,4))
plt.title('Bronx Total Units histogram',fontsize=16)
plt.hist(bronx['TOTAL_UNITS'].dropna(),edgecolor='k',color='blue',bins=30)
plt.show()
